# %%
import os
import pandas as pd
from pathlib import Path  
import time
import math
import numpy as np

path = "D:\Extracted Data"
dir_list = os.listdir(path)

# %%
start_time = time.time()
x = pd.DataFrame()
y = pd.DataFrame()
for file in dir_list:
    filepath = path + '/' + file
    df = pd.read_csv(filepath)

    # # Adding Velocity Magnitude
    # x = df.iloc[:,10]
    # y = df.iloc[:,11]
    # velocityMagnitude = np.sqrt(np.square(x) + np.square(y))
    # # df.insert(11, "VelocityMagnitude", velocityMagnitude, True)
    # df['VelocityMagnitude'] = velocityMagnitude

    # # Adding area
    # major = df.iloc[:,2]
    # minor = df.iloc[:,3]
    # area = math.pi * major * minor
    # # df.insert(4, "Area", area, True)
    # df['Area'] = area

    # # Adding ratio of major to minor
    # major = df.iloc[:,2]
    # minor = df.iloc[:,3]
    # list = []
    # for i in range(major.size):
    #     if major[i] > minor[i]:
    #         ratio = major[i]/minor[i]
    #     else:
    #         ratio = minor[i]/major[i]
    #     list.append(ratio)
    # list = np.array(list)
    # df.insert(5, "AxisRatio", list, True)


    df.to_csv(filepath, index=False)
    print('Modifying ' + file + 'csv')
# Out:
# Modifying R19040818488460_Params.csvcsv
# Modifying R19040908037522_Params.csvcsv
# Modifying R19040908037539_Params.csvcsv
# Modifying R19040908037575_Params.csvcsv
# Modifying R19040908037662_Params.csvcsv
# Modifying R19040908037669_Params.csvcsv
# Modifying R19040908037690_Params.csvcsv
# Modifying R19041001227237_Params.csvcsv
# Modifying R19041001227477_Params.csvcsv
# Modifying R19041002137218_Params.csvcsv
# Modifying R19041002137345_Params.csvcsv
# Modifying R17061402257452_Params.csvcsv
# Modifying R17061402257667_Params.csvcsv
# Modifying R17061402257788_Params.csvcsv
# Modifying R17061402257829_Params.csvcsv
# Modifying R17061402257851_Params.csvcsv
# Modifying R17061402257927_Params.csvcsv
# Modifying R17061402258162_Params.csvcsv
# Modifying R17061402258164_Params.csvcsv
# Modifying R17061411227765_Params.csvcsv
# Modifying R17061411228013_Params.csvcsv
# Modifying R17061411228044_Params.csvcsv
# Modifying R17061411228145_Params.csvcsv
# ...

# %%
df.head(49)
# Out:
#     EventID                                          FileName  \
# 0   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 1   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 2   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 3   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 4   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 5   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 6   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 7   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 8   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 9   S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 10  S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 11  S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 12  S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# 13  S858968  vil/2019/SEVIR_VIL_STORMEVENTS_2019_0701_1231.h5
# ...

# %%
# major = df.iloc[:,2]
# minor = df.iloc[:,3]
# list = []
# for i in range(major.size):
#     if major[i] > minor[i]:
#         ratio = major[i]/minor[i]
#     else:
#         ratio = minor[i]/major[i]
#     list.append(ratio)
# list = np.array(list)
# df.insert(5, "AxisRatio", list, True)
# df.head()

# %%
# df['VelocityMagnitude'] =
